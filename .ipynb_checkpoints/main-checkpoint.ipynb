# %%
# %matplotlib inline

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
from shapely.affinity import affine_transform
from shapely.geometry import mapping
import xml.etree.ElementTree as ET
from xml.dom import minidom

# %%
# Replace 'path/to/your_shapefile.shp' with the actual path to your shapefile

geojson_path = '2024-01-31_siedlce_EIK_2180.geojson'

# Siedlce OSM: '2024-01-24_siedlce_2180.geojson'
# Siedlce ELEMENTY SIECIOWE: '2024-01-24_elem-siec_isa.geojson'
# Siedlce EIK: '2024-01-31_siedlce_EIK_2180.geojson'
# Warka OSM: '2024-01-31_warka_osm_2180.geojson'
# '2024-01-31_warka_osm_2180.geojson'
#Skierniewice: '2024-02-01_skierniewice_2180_osm.geojson'

#24-04

#24-04-24_template_geo2scheme_geojson_NET-ELEMENTS-input_Tarnowo-Pom.geojson

# %%
# Read the shapefile
gdf = gpd.read_file(geojson_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Read the shapefile
# ----> 2 gdf = gpd.read_file(geojson_path)
#
# NameError: name 'gpd' is not defined

# %%
# Explore the GeoDataFrame
print(gdf.head())
# Out:
#    id              X              Y           Z           Typ  \
# 0   2  725250.001186  481171.012228  157.271900  sygnalizator
# 1   5  725346.916111  480943.062366  156.566692  sygnalizator
# 2   8  723167.230155  482722.402488  157.885930  sygnalizator
# 3   9  723203.917593  482700.550697  157.886403  sygnalizator
# 4   4  725356.008256  480947.543565  156.789799  sygnalizator
#
#    Liczba detekcji                                        Zdjęcia UAV  \
# 0             76.0  <img src='lib/leaflet/zdjecia/100_0088_0076.JP...
# 1             73.0  <img src='lib/leaflet/zdjecia/100_0123_0027.JP...
# 2             13.0  <img src='lib/leaflet/zdjecia/100_0026_0021.JP...
# 3             16.0  <img src='lib/leaflet/zdjecia/100_0026_0024.JP...
# 4             75.0  <img src='lib/leaflet/zdjecia/100_0123_0027.JP...
#
#                                              id_bbox  \
# 0  9217, 9219, 9220, 9227, 9228, 9229, 9230, 9232...
# 1  9235, 9237, 9239, 9244, 9246, 9248, 9253, 9255...
# 2  9343, 14891, 14892, 14893, 14894, 15011, 15014...
# 3  9344, 14896, 14897, 14994, 14995, 14996, 14998...
# 4  9234, 9236, 9238, 9245, 9247, 9249, 9252, 9254...
#
#                                                Cechy Oznaczenie  \
# 0  {'liczba_komor': '5', 'pas_sw': 'true', 'rodza...          Z
# 1  {'liczba_komor': '5', 'pas_sw': 'true', 'rodza...          X
# 2  {'liczba_komor': '2', 'pas_sw': 'false', 'rodz...      Tm203
# 3  {'liczba_komor': '2', 'pas_sw': 'false', 'rodz...      Tm201
# 4  {'liczba_komor': '5', 'pas_sw': 'true', 'rodza...          Y
#
#    azimuth_inherit  Azymut     Kierunek  autoid  \
# 0              308     321  nieparzysty       2
# 1              312     334     parzysty       5
# 2              127     127  nieparzysty       8
# 3              127     127  nieparzysty       9
# 4              312     334     parzysty       4
#
#                                            Karta EIK symbol_sygn Dokumentacja  \
# 0  <a href="/FunctionalInfrastructureElements/Det...        5wys         None
# 1  <a href="/FunctionalInfrastructureElements/Det...        5wys         None
# 2  <a href="/FunctionalInfrastructureElements/Det...        2wys         None
# 3  <a href="/FunctionalInfrastructureElements/Det...        2wys         None
# 4  <a href="/FunctionalInfrastructureElements/Det...        5wys         None
#
#        km km_string                       geometry
# 0  93.657    93.657  POINT (725250.001 481171.012)
# 1  93.901    93.901  POINT (725346.916 480943.062)
# 2  91.064    91.064  POINT (723167.230 482722.402)
# 3  91.106    91.106  POINT (723203.918 482700.551)
# 4  93.901    93.901  POINT (725356.008 480947.544)

# %%
# Visualize the data
gdf.plot(figsize=(15, 15))
# Out:
# <Axes: >

# %%
rotate_angle = 37

#Siedlce: 38

# %%
df_rotated2 = gdf.rotate(rotate_angle, origin=gdf.unary_union.centroid)

# %%
df_rotated2.plot(figsize=(20, 20))
# Out:
# <Axes: >

# %%
# Explore the GeoDataFrame
print(gdf.head())
# Out:
#    id              X              Y           Z           Typ  \
# 0   2  725250.001186  481171.012228  157.271900  sygnalizator
# 1   5  725346.916111  480943.062366  156.566692  sygnalizator
# 2   8  723167.230155  482722.402488  157.885930  sygnalizator
# 3   9  723203.917593  482700.550697  157.886403  sygnalizator
# 4   4  725356.008256  480947.543565  156.789799  sygnalizator
#
#    Liczba detekcji                                        Zdjęcia UAV  \
# 0             76.0  <img src='lib/leaflet/zdjecia/100_0088_0076.JP...
# 1             73.0  <img src='lib/leaflet/zdjecia/100_0123_0027.JP...
# 2             13.0  <img src='lib/leaflet/zdjecia/100_0026_0021.JP...
# 3             16.0  <img src='lib/leaflet/zdjecia/100_0026_0024.JP...
# 4             75.0  <img src='lib/leaflet/zdjecia/100_0123_0027.JP...
#
#                                              id_bbox  \
# 0  9217, 9219, 9220, 9227, 9228, 9229, 9230, 9232...
# 1  9235, 9237, 9239, 9244, 9246, 9248, 9253, 9255...
# 2  9343, 14891, 14892, 14893, 14894, 15011, 15014...
# 3  9344, 14896, 14897, 14994, 14995, 14996, 14998...
# 4  9234, 9236, 9238, 9245, 9247, 9249, 9252, 9254...
#
#                                                Cechy Oznaczenie  \
# 0  {'liczba_komor': '5', 'pas_sw': 'true', 'rodza...          Z
# 1  {'liczba_komor': '5', 'pas_sw': 'true', 'rodza...          X
# 2  {'liczba_komor': '2', 'pas_sw': 'false', 'rodz...      Tm203
# 3  {'liczba_komor': '2', 'pas_sw': 'false', 'rodz...      Tm201
# 4  {'liczba_komor': '5', 'pas_sw': 'true', 'rodza...          Y
#
#    azimuth_inherit  Azymut     Kierunek  autoid  \
# 0              308     321  nieparzysty       2
# 1              312     334     parzysty       5
# 2              127     127  nieparzysty       8
# 3              127     127  nieparzysty       9
# 4              312     334     parzysty       4
#
#                                            Karta EIK symbol_sygn Dokumentacja  \
# 0  <a href="/FunctionalInfrastructureElements/Det...        5wys         None
# 1  <a href="/FunctionalInfrastructureElements/Det...        5wys         None
# 2  <a href="/FunctionalInfrastructureElements/Det...        2wys         None
# 3  <a href="/FunctionalInfrastructureElements/Det...        2wys         None
# 4  <a href="/FunctionalInfrastructureElements/Det...        5wys         None
#
#        km km_string                       geometry
# 0  93.657    93.657  POINT (725250.001 481171.012)
# 1  93.901    93.901  POINT (725346.916 480943.062)
# 2  91.064    91.064  POINT (723167.230 482722.402)
# 3  91.106    91.106  POINT (723203.918 482700.551)
# 4  93.901    93.901  POINT (725356.008 480947.544)

# %%
# Explore the GeoDataFrame
print(df_rotated2.head())
# Out:
# 0    POINT (725539.335 482032.726)
# 1    POINT (725753.918 481909.002)
# 2    POINT (722942.310 482018.279)
# 3    POINT (722984.760 482022.906)
# 4    POINT (725758.482 481918.053)
# dtype: geometry

# %%
# TO DELETE

# Save the GeoDataFrame as a GeoJSON file
df_rotated2.to_file('temp.geojson', driver='GeoJSON')

# %%
#TO DELETE
geojson_path2 = 'temp.geojson'

# %%
# Wczytaj plik GeoJSON
gdf = gpd.read_file(geojson_path2)

# %%
# Oblicz minimalne współrzędne (xmin, ymin) dla każdego z geometrii
min_coords = gdf.bounds.min()

# %%
# Przesuń wszystkie geometrie w lewo i w dół o wartości minimalnych współrzędnych
gdf['geometry'] = gdf.translate(xoff=-min_coords['minx'], yoff=-min_coords['miny'])

# %%
# Explore the GeoDataFrame
print(gdf.head())
# Out:
#                    geometry
# 0  POINT (3387.534 154.770)
# 1   POINT (3602.117 31.046)
# 2   POINT (790.509 140.322)
# 3   POINT (832.959 144.950)
# 4   POINT (3606.682 40.097)

# %%
gdf.plot(figsize=(20, 20))
# Out:
# <Axes: >

# %%
# Function to scale the x-coordinates by a factor
def scale_x(geometry, factor):
    return affine_transform(geometry, [factor, 0, 0, 1, 0, 0])

# %%
# Apply the scaling operation to the geometry column
gdf['geometry'] = gdf['geometry'].apply(scale_x, factor=1/4)

# %%
# Explore the GeoDataFrame
print(gdf.head())
# Out:
#                   geometry
# 0  POINT (846.883 154.770)
# 1   POINT (900.529 31.046)
# 2  POINT (197.627 140.322)
# 3  POINT (208.240 144.950)
# 4   POINT (901.670 40.097)

# %%
df_rotated3 = gdf.rotate(0, origin=gdf.unary_union.centroid)

# %%
df_rotated3.plot(figsize=(20, 20))
# Out:
# <Axes: >

# %%
print(df_rotated3.head())
# Out:
# 0      MULTILINESTRING ((0.000 37.771, 15.401 35.440))
# 1    MULTILINESTRING ((15.401 35.440, 242.930 39.507))
# 2    MULTILINESTRING ((14.906 25.906, 152.137 31.306))
# 3    MULTILINESTRING ((15.256 21.696, 165.045 27.134))
# 4    MULTILINESTRING ((152.137 31.306, 165.045 27.1...
# dtype: geometry

# %%
# Save the GeoDataFrame as a GeoJSON file
df_rotated3.to_file('2024-01-24_elem-siec_isa_rotated.geojson', driver='GeoJSON')

# %%
# RailML XML namespace
railml_ns = {"railml": "http://www.railml.org/schemas/2013"}

# Create RailML XML document
railml_root = ET.Element("railml", nsmap=railml_ns)

# Iterate through GeoDataFrame features
for index, row in gdf.iterrows():
    # Extract geometry from GeoDataFrame
    geometry = row['geometry']

    # Convert Shapely geometry to GeoJSON-like dictionary
    geometry_dict = mapping(geometry)

    # Create RailML track element
    track_element = ET.SubElement(railml_root, "track", nsmap=railml_ns)

    # Create RailML geometry element
    geometry_element = ET.SubElement(track_element, "geometry", nsmap=railml_ns)

    # Add RailML point elements based on GeoJSON-like geometry
    for coord in geometry_dict['coordinates']:
        point_element = ET.SubElement(geometry_element, "point", nsmap=railml_ns)
        point_element.set("x", str(coord[0]))
        point_element.set("y", str(coord[1]))
        # Add additional attributes as needed

# Create a formatted XML string
xml_string = ET.tostring(railml_root, encoding='utf-8')
xml_pretty_string = minidom.parseString(xml_string).toprettyxml(indent="  ")

# Save or print the RailML XML
with open("output_railml.xml", "w") as xml_file:
    xml_file.write(xml_pretty_string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 24
#      22     for coord in geometry_dict['coordinates']:
#      23         point_element = ET.SubElement(geometry_element, "point", nsmap=railml_ns)
# ---> 24         point_element.set("x", str(coord[0]))
#      25         point_element.set("y", str(coord[1]))
#      26         # Add additional attributes as needed
#      27
#      28 # Create a formatted XML string
#
# TypeError: 'float' object is not subscriptable

# %%
# Save the RailML XML to a file
output_file_path = "output_railml.xml"
with open(output_file_path, "w") as xml_file:
    xml_file.write(xml_pretty_string)

# Print a message indicating where the XML is saved
print(f"RailML XML saved to: {output_file_path}")
